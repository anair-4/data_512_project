# %% [markdown]
# # US EPA Air Quality System API Example
# This example illustrates how to request data from the US Environmental Protection Agency (EPA) Air Quality Service (AQS) API. This is a historical API and does not provide real-time air quality data. The [documentation](https://aqs.epa.gov/aqsweb/documents/data_api.html) for the API provides definitions of the different call parameter and examples of the various calls that can be made to the API.
#
# This notebook works systematically through example calls, requesting an API key, using 'list' to get various IDs and parameter values, and using 'daily summary' to get summary data that meets specific condistions. The notebook contains example function definitions that could be reused in other code. In general, the notebook explains each step along the way, referring back to possible output. Some of the explanations are tailored to the specific example requests of the API. Changing values to explore the results of the API is probably useful, but that will result in some explanations being out of sync with the outputs.
#
# The US EPA was created in the early 1970's. The EPA reports that they only started broad based monitoring with standardized quality assurance procedures in the 1980's. Many counties will have data starting somewhere between 1983 and 1988. However, some counties still do not have any air quality monitoring stations. The API helps resolve this by providing calls to search for monitoring stations and data using either station ids, or a county designation or a geographic bounding box. This example code provides examples of the county based and bounding box based API calls. Some [additional information on the Air Quality System can be found in the EPA FAQ](https://www.epa.gov/outdoor-air-quality-data/frequent-questions-about-airdata) on the system.
#
# The end goal of this example is to get to some values that we might use for the Air Quality Index or AQI. You might see this reported on the news, most often around smog, but more frequently with regard to smoke. The AQI index is meant to tell us something about how healthy or clean the air is on any day. The AQI is actually a somewhat complext measure. When I started this example I looked up [how to calculate the AQI](https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf) so that I would know roughly what goes into that value.
#
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - September 5, 2023

# %%
# 
#    These are standard python modules
#
#import json, time, urllib.parse
import json, time
#
#    The 'requests' module is a distribution module for making web requests.
#
import requests
import numpy as np

# %%
#########
#
#    CONSTANTS
#

#
#    This is the root of all AQS API URLs
#
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'

#
#    These are 'actions' we can ask the API to take or requests that we can make of the API
#
#    Sign-up request - generally only performed once - unless you lose your key
API_ACTION_SIGNUP = '/signup?email={email}'
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

# %% [markdown]
# ## Example 1. Making a sign-up request
#
# Before you can use the API you need to request a key. You will use an email address to make the request. The EPA then sends a confirmation email link and a 'key' that you use for all other requests.
#
# You only need to sign-up once, unless you want to invalidate your current key (by getting a new key) or you lose your key.

# %%
#
#    This implements the sign-up request. The parameters are standardized so that this function definition matches
#    all of the others. However, the easiest way to call this is to simply call this function with your preferred
#    email address.
#
def request_signup(email_address = None,
                   endpoint_url = API_REQUEST_URL, 
                   endpoint_action = API_ACTION_SIGNUP, 
                   request_template = AQS_REQUEST_TEMPLATE,
                   headers = None):
    
    # Make sure we have a string - if you don't have access to this email addres, things might go badly for you
    if email_address:
        request_template['email'] = email_address        
    if not request_template['email']: 
        raise Exception("Must supply an email address to call 'request_signup()'")
    
    # Compose the signup url - create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#    A SIGNUP request is only to be done once, to request a key. A key is sent to that email address and needs to be confirmed with a click through
#    This code should probably be commented out after you've made your key request to make sure you don't accidentally make a new sign-up request
#
print("Requesting SIGNUP ...")
response = request_signup("anair4@uw.edu")
print(json.dumps(response,indent=4))
#
# Out:
# Requesting SIGNUP ...
# {
#     "Header": [
#         {
#             "status": "Success",
#             "request_time": "2023-11-08T20:23:21-05:00",
#             "url": "https://aqs.epa.gov/data/api/signup?email=anair4@uw.edu"
#         }
#     ],
#     "Data": [
#         "You should receive an email containing your new key shortly."
#     ]
# }

# %% [markdown]
# A response to the signup request might look something like this.
#
#
#     Requesting SIGNUP ...
#     {
#         "Header": [
#             {
#                 "status": "Success",
#                 "request_time": "2023-08-07T17:03:27-04:00",
#                 "url": "https://aqs.epa.gov/data/api/signup?email=dwmc@uw.edu"
#             }
#         ],
#         "Data": [
#             "You should receive a registration confirmation email with a link for confirming your email shortly."
#         ]
#     }

# %% [markdown]
# **Note:** The code below relies on a user module called apikeys that is a key manager. You don't need that to make this code work. You can use the email you used for your sign-up request and the key that you got in email. Assign your email address to "USERNAME" and your key to "APIKEY" as constants and the remaining cells in the notbook should work.

# %%
USERNAME = "anair4@uw.edu"
APIKEY = "russetcat88"

# %%
#
#   Once we have a list of the classes or groups of possible sensors, we can find the sensor IDs that make up that class (group)
#   The one that looks to be associated with the Air Quality Index is "AQI POLLUTANTS"
#   We'll use that to make another list request.
#
AQI_PARAM_CLASS = "AQI POLLUTANTS"

# %% [markdown]
# We should now have (above) a response containing a set of sensor ID numbers. The list should include the sensor numbers as well as a description or name for each sensor.
#
# The EPA AQS API has limits on some call parameters. Specifically, when we request data for sensors we can only specify a maximum of 5 different sensor values to return. This means we cannot get all of the Air Quality Index parameters in one request for data. We have to break it up.
#
# What I did below was to break the request into two logical groups, the AQI sensors that sample gasses and the AQI sensors that sample particles in the air.

# %%
#
#   Given the set of sensor codes, now we can create a parameter list or 'param' value as defined by the AQS API spec.
#   It turns out that we want all of these measures for AQI, but we need to have two different param constants to get
#   all seven of the code types. We can only have a max of 5 sensors/values request per param.
#
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"
#   
#

# %% [markdown]
# Air quality monitoring stations are located all over the US at different locations. We will need some sample locations to experiment with different locations to see what kinds of values come back from different sensor requests.
#
# This list includes the [FIPS](https://www.census.gov/library/reference/code-lists/ansi.html) number for the state and county as a 5 digit string. This format, the 5 digit string, is a 'old' format that is still widely used. There are new codes that may eventually be adopted for the US government information systems. But FIPS is currently what the AQS uses, so that's what is in the list as the constant.
#
# Just two example cities to explore.

# %%
#
#   We'll use these two city locations in the examples below.
#

CITY_LOCATIONS = {
    'lw' :       {'city'   : 'Benicia',
                       'county' : 'Solano',
                       'state'  : 'California',
                       'fips'   : '05290',
                       'latlon' : [38.052147, -122.153893] }
}

# %% [markdown]
# Given our CITY_LOCATIONS constant we can now find which monitoring locations are nearby. One option is to use the county to define the area we're interest in. You can get the EPA to list their monitoring stations by county. You can also get a set of monitoring stations by using a bounding box of latitude, longitude points. For this example, we'll use the county approach. There is a bounding box example later in this notebook.

# %% [markdown]
# ## Example 3. Making a daily summary request
#
# The function below is designed to encapsulate requests to the EPA AQS API. When calling the function one should create/copy a parameter template, then initialize that template with values that won't change with each call. Then on each call simply pass in the parameters that need to change, like date ranges.
#
# Another function below provides an example of extracting values and restructuring the response to make it a little more usable.

# %%
#
#    This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['lw']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['lw']['fips'][2:]

# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))

request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2021
particulate_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants ...
# Looks like the response generated no data. You might take a closer look at your request and the response data.

# %% [markdown]
# ## Find stations with close to the destination that have data

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute a rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
#
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # remember we have both gaseous and particulates
# 
#   We got the monitoring stations for Bend OR above (Deschutes county) - let's work with that one again
request_data['state'] = CITY_LOCATIONS['lw']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['lw']['fips'][2:]
#
# the first example uses the default - request monitors by county, we'll just use a recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731")
#
# the response should be similar to the 'list' request above - but in this case we should only get monitors that
# monitor the AQI_PARAMS_PARTICULATES set of params.
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# {
#     "Header": [
#         {
#             "status": "No data matched your selection",
#             "request_time": "2023-11-08T20:28:52-05:00",
#             "url": "https://aqs.epa.gov/data/api/monitors/byCounty?email=anair4@uw.edu&key=russetcat88&param=81102,88101,88502&bdate=20210701&edate=20210731&state=05&county=290",
#             "rows": 0
#         }
#     ],
#     "Data": []
# }

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['lw'],scale=1.0)

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="19630101", end_date="20230131",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "0002",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-03-01",
#         "close_date": "1993-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1986-03-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 890,
#         "latitude": 37.936013,
#         "longitude": -122.026154,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 13.0,
#         "elevation": 26.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": "Concord",
#         "address": "2956-A TREAT BOULEVARD",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Concord",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "0002",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-08",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2019-02-23",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 890,
#         "latitude": 37.936013,
#         "longitude": -122.026154,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 13.0,
#         "elevation": 26.0,
#         "probe_height": 5.9,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Concord",
#         "address": "2956-A TREAT BOULEVARD",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Concord",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2004-06-14",
#         "close_date": "2005-06-09",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2004-06-14",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0145",
#         "monitoring_agency": "California Air Resources Board",
#         "si_id": 91969,
#         "latitude": 37.7338,
#         "longitude": -122.3824,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 82.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": "San Francisco - Bayview Hunters Point",
#         "address": "100 WHITNEY YOUNG CIRCLE, SAN FRANCISCO",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2007-04-06",
#         "close_date": "2008-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2007-04-06",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 93759,
#         "latitude": 38.0656,
#         "longitude": -122.1507,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 6.0,
#         "elevation": 109.0,
#         "probe_height": 4.6,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Benicia - VIP",
#         "address": "E SECOND ST, BENICIA",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Benicia",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0011",
#         "parameter_code": "88502",
#         "poc": 5,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2009-02-12",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "810",
#         "last_method_description": "Met One SASS/SuperSASS Teflon - Gravimetric",
#         "last_method_begin_date": "2009-02-12",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 94938,
#         "latitude": 37.814781,
#         "longitude": -122.282347,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 6.0,
#         "elevation": 0.0,
#         "probe_height": 5.2,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Oakland West",
#         "address": "1100 21st Street",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2011-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION; POPULATION EXPOSURE; REGIONAL TRANSPORT",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2011-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1532,
#         "latitude": 38.102507,
#         "longitude": -122.237976,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 6.0,
#         "probe_height": 5.8,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Vallejo",
#         "address": "304 TUOLUMNE ST.",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vallejo",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 4,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2013-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "QUALITY ASSURANCE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1532,
#         "latitude": 38.102507,
#         "longitude": -122.237976,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 6.0,
#         "probe_height": 5.8,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Vallejo",
#         "address": "304 TUOLUMNE ST.",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vallejo",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "0002",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2013-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2013-01-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 890,
#         "latitude": 37.936013,
#         "longitude": -122.026154,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 13.0,
#         "elevation": 26.0,
#         "probe_height": 6.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Concord",
#         "address": "2956-A TREAT BOULEVARD",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Concord",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "0002",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-11-04",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1994-01-02",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 890,
#         "latitude": 37.936013,
#         "longitude": -122.026154,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 13.0,
#         "elevation": 26.0,
#         "probe_height": 5.8,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Concord",
#         "address": "2956-A TREAT BOULEVARD",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Concord",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "041",
#         "site_number": "0001",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-11-04",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1994-01-02",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1128,
#         "latitude": 37.97231,
#         "longitude": -122.520004,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 2.0,
#         "elevation": 3.0,
#         "probe_height": 8.3,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Rafael",
#         "address": "534 4TH ST.",
#         "state_name": "California",
#         "county_name": "Marin",
#         "city_name": "San Rafael",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "055",
#         "site_number": "0003",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1988-04-01",
#         "close_date": "2016-10-17",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "QUALITY ASSURANCE",
#         "last_method_code": "141",
#         "last_method_description": "Tisch Environ Model-6070 PM10 Hi-Vol - Gravimetric",
#         "last_method_begin_date": "2004-06-08",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1190,
#         "latitude": 38.310942,
#         "longitude": -122.296189,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 13.0,
#         "probe_height": 5.5,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Napa",
#         "address": "2552 JEFFERSON AVE.",
#         "state_name": "California",
#         "county_name": "Napa",
#         "city_name": "Napa",
#         "cbsa_code": "34900",
#         "cbsa_name": "Napa, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": "2011-02-28",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2008-11-05",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1532,
#         "latitude": 38.102507,
#         "longitude": -122.237976,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 6.0,
#         "probe_height": 6.3,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Vallejo",
#         "address": "304 TUOLUMNE ST.",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vallejo",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "0002",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2000-01-01",
#         "close_date": "2012-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2008-10-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 890,
#         "latitude": 37.936013,
#         "longitude": -122.026154,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 13.0,
#         "elevation": 26.0,
#         "probe_height": 7.6,
#         "pl_probe_location": null,
#         "local_site_name": "Concord",
#         "address": "2956-A TREAT BOULEVARD",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Concord",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0006",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-06-14",
#         "close_date": "2005-06-14",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2004-06-14",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 91969,
#         "latitude": 37.7338,
#         "longitude": -122.3824,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 82.0,
#         "probe_height": 4.2,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Francisco - Bayview Hunters Point",
#         "address": "100 WHITNEY YOUNG CIRCLE, SAN FRANCISCO",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0015",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2018-04-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "MICROSCALE",
#         "measurement_scale_def": "0 M TO 100 M",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2018-04-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NEAR ROAD",
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 104234,
#         "latitude": 37.701222,
#         "longitude": -121.903019,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 101.0,
#         "probe_height": 4.6,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Pleasanton - Owens Ct",
#         "address": "Owens Ct.",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Pleasanton",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1990-08-01",
#         "close_date": "1998-06-30",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "062",
#         "last_method_description": "HI-VOL-WEDDING-INLET - GRAVIMETRIC",
#         "last_method_begin_date": "1997-03-29",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 859,
#         "latitude": 37.710229,
#         "longitude": -122.116899,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 43.0,
#         "probe_height": 1.5,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "San Leandro",
#         "address": "HOSPITAL-15400 FOOTHILL BLVD,SAN LEANDRO",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Castro Valley",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "3001",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1999-08-01",
#         "close_date": "2008-07-17",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2001-08-17",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 900,
#         "latitude": 38.029258,
#         "longitude": -121.896866,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 2.0,
#         "probe_height": 5.6,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Pittsburg - W 10th St.",
#         "address": "583 W. 10TH ST., PITTSBURG",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "Pittsburg",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0005",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-03-01",
#         "close_date": "1993-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1986-03-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1376,
#         "latitude": 37.765946,
#         "longitude": -122.399044,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 5.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": "San Francisco",
#         "address": "10 ARKANSAS ST.",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "3001",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1989-01-01",
#         "close_date": "1989-04-28",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "052",
#         "last_method_description": "HI-VOL-SA321A - GRAVIMETRIC",
#         "last_method_begin_date": "1989-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0145",
#         "monitoring_agency": "California Air Resources Board",
#         "si_id": 1537,
#         "latitude": 38.3514,
#         "longitude": -121.9941,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 59.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": "Vacaville-Merchant Street",
#         "address": "650 MERCHANT ST., VACAVILLE",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vacaville",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 5,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "810",
#         "last_method_description": "Met One SASS/SuperSASS Teflon - Gravimetric",
#         "last_method_begin_date": "2004-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1532,
#         "latitude": 38.102507,
#         "longitude": -122.237976,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 6.0,
#         "probe_height": 6.9,
#         "pl_probe_location": null,
#         "local_site_name": "Vallejo",
#         "address": "304 TUOLUMNE ST.",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vallejo",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0005",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2009-10-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2009-10-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1376,
#         "latitude": 37.765946,
#         "longitude": -122.399044,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 5.0,
#         "probe_height": 8.3,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Francisco",
#         "address": "10 ARKANSAS ST.",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "055",
#         "site_number": "0003",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2012-12-13",
#         "close_date": "2018-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2012-12-13",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1190,
#         "latitude": 38.310942,
#         "longitude": -122.296189,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 13.0,
#         "probe_height": 5.5,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Napa",
#         "address": "2552 JEFFERSON AVE.",
#         "state_name": "California",
#         "county_name": "Napa",
#         "city_name": "Napa",
#         "cbsa_code": "34900",
#         "cbsa_name": "Napa, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0013",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2016-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "MICROSCALE",
#         "measurement_scale_def": "0 M TO 100 M",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2016-07-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NEAR ROAD",
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 102205,
#         "latitude": 37.864767,
#         "longitude": -122.302741,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 2.7,
#         "probe_height": 5.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Berkeley- Aquatic Park",
#         "address": "1 Bolivar Dr",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Not in a City",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "1004",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2016-10-19",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "QUALITY ASSURANCE",
#         "last_method_code": "141",
#         "last_method_description": "Tisch Environ Model-6070 PM10 Hi-Vol - Gravimetric",
#         "last_method_begin_date": "2016-10-19",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 91266,
#         "latitude": 37.9604,
#         "longitude": -122.356811,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 20.0,
#         "probe_height": 6.4,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Pablo",
#         "address": "1865 D RUMRILL BLVD, San Pablo",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "San Pablo",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-01-01",
#         "close_date": "2010-09-14",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2004-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1532,
#         "latitude": 38.102507,
#         "longitude": -122.237976,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 6.0,
#         "probe_height": 6.9,
#         "pl_probe_location": null,
#         "local_site_name": "Vallejo",
#         "address": "304 TUOLUMNE ST.",
#         "state_name": "California",
#         "county_name": "Solano",
#         "city_name": "Vallejo",
#         "cbsa_code": "46700",
#         "cbsa_name": "Vallejo-Fairfield, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "2004",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2007-12-13",
#         "close_date": "2010-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "141",
#         "last_method_description": "Tisch Environ Model-6070 PM10 Hi-Vol - Gravimetric",
#         "last_method_begin_date": "2007-12-13",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 94086,
#         "latitude": 37.877794,
#         "longitude": -122.30129,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 6.0,
#         "probe_height": 4.4,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Berkeley",
#         "address": "1340 Sixth Street",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Berkeley",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0011",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2009-02-25",
#         "close_date": "2012-12-11",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2009-02-25",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 94938,
#         "latitude": 37.814781,
#         "longitude": -122.282347,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 6.0,
#         "elevation": 0.0,
#         "probe_height": 5.2,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Oakland West",
#         "address": "1100 21st Street",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0011",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2012-12-18",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2012-12-18",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 94938,
#         "latitude": 37.814781,
#         "longitude": -122.282347,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 6.0,
#         "elevation": 0.0,
#         "probe_height": 5.2,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Oakland West",
#         "address": "1100 21st Street",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "055",
#         "site_number": "0003",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-11-04",
#         "close_date": "2016-10-17",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "141",
#         "last_method_description": "Tisch Environ Model-6070 PM10 Hi-Vol - Gravimetric",
#         "last_method_begin_date": "2005-07-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1190,
#         "latitude": 38.310942,
#         "longitude": -122.296189,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 13.0,
#         "probe_height": 5.5,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Napa",
#         "address": "2552 JEFFERSON AVE.",
#         "state_name": "California",
#         "county_name": "Napa",
#         "city_name": "Napa",
#         "cbsa_code": "34900",
#         "cbsa_name": "Napa, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0005",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-01-01",
#         "close_date": "2009-09-30",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "145",
#         "last_method_description": "R & P Model 2025 PM-2.5 Sequential Air Sampler w/VSCC - Gravimetric",
#         "last_method_begin_date": "2008-12-02",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1376,
#         "latitude": 37.765946,
#         "longitude": -122.399044,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 5.0,
#         "probe_height": 8.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Francisco",
#         "address": "10 ARKANSAS ST.",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "095",
#         "site_number": "0006",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2007-04-01",
#         "close_date": "2008-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "731",
# ...
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2009-10-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2009-10-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 93907,
#         "latitude": 37.743065,
#         "longitude": -122.169935,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 6.0,
#         "elevation": 11.0,
#         "probe_height": 8.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Oakland",
#         "address": "9925 International Blvd",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0012",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2014-02-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "MOBILE",
#         "measurement_scale": "MICROSCALE",
#         "measurement_scale_def": "0 M TO 100 M",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2014-02-01",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": "NEAR ROAD",
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 97584,
#         "latitude": 37.793624,
#         "longitude": -122.263376,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 3.9,
#         "probe_height": 6.4,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Laney College",
#         "address": "Laney College Eighth St. parking lot Aisle J",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "1003",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1997-05-10",
#         "close_date": "2002-08-24",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1997-05-10",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 897,
#         "latitude": 37.9642,
#         "longitude": -122.3403,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 15.0,
#         "probe_height": 8.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Pablo - El Portal Center",
#         "address": "UNIT 759 EL PORTAL SHOPPING CENTER, San Pablo",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "San Pablo",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "075",
#         "site_number": "0005",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-11-16",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1994-01-02",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1376,
#         "latitude": 37.765946,
#         "longitude": -122.399044,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 5.0,
#         "probe_height": 7.6,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Francisco",
#         "address": "10 ARKANSAS ST.",
#         "state_name": "California",
#         "county_name": "San Francisco",
#         "city_name": "San Francisco",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "2004",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2007-12-13",
#         "close_date": "2010-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE; SOURCE ORIENTED",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2007-12-13",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 94086,
#         "latitude": 37.877794,
#         "longitude": -122.30129,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 15.0,
#         "elevation": 6.0,
#         "probe_height": 4.8,
#         "pl_probe_location": "POLE",
#         "local_site_name": "Berkeley",
#         "address": "1340 Sixth Street",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Berkeley",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "1004",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2012-12-10",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2012-12-10",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 91266,
#         "latitude": 37.9604,
#         "longitude": -122.356811,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 20.0,
#         "probe_height": 6.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Pablo",
#         "address": "1865 D RUMRILL BLVD, San Pablo",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "San Pablo",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "055",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2018-04-01",
#         "close_date": "2021-05-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2018-04-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 104235,
#         "latitude": 38.278849,
#         "longitude": -122.275024,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 10.0,
#         "probe_height": 4.9,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "Napa Valley College",
#         "address": "Magnolia Drive and Route 221",
#         "state_name": "California",
#         "county_name": "Napa",
#         "city_name": "Napa",
#         "cbsa_code": "34900",
#         "cbsa_name": "Napa, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "013",
#         "site_number": "1004",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2002-09-13",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "141",
#         "last_method_description": "Tisch Environ Model-6070 PM10 Hi-Vol - Gravimetric",
#         "last_method_begin_date": "2002-09-13",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": "Y",
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 91266,
#         "latitude": 37.9604,
#         "longitude": -122.356811,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 20.0,
#         "probe_height": 6.4,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Pablo",
#         "address": "1865 D RUMRILL BLVD, San Pablo",
#         "state_name": "California",
#         "county_name": "Contra Costa",
#         "city_name": "San Pablo",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "001",
#         "site_number": "0008",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-01-01",
#         "close_date": "2009-03-03",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": null,
#         "last_method_description": " - ",
#         "last_method_begin_date": null,
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 91264,
#         "latitude": 37.817118,
#         "longitude": -122.280454,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 20.0,
#         "elevation": 14.0,
#         "probe_height": 7.5,
#         "pl_probe_location": null,
#         "local_site_name": "Oakland - Filbert St.",
#         "address": "2419 FILBERT ST, OAKLAND, CA",
#         "state_name": "California",
#         "county_name": "Alameda",
#         "city_name": "Oakland",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "06",
#         "county_code": "041",
#         "site_number": "0001",
#         "parameter_code": "88101",
#         "poc": 3,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2009-10-27",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "170",
#         "last_method_description": "Met One BAM-1020 Mass Monitor w/VSCC - Beta Attenuation",
#         "last_method_begin_date": "2009-10-27",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0086",
#         "monitoring_agency": "Bay Area Air Quality Management District",
#         "si_id": 1128,
#         "latitude": 37.97231,
#         "longitude": -122.520004,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 2.0,
#         "elevation": 3.0,
#         "probe_height": 8.6,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": "San Rafael",
#         "address": "534 4TH ST.",
#         "state_name": "California",
#         "county_name": "Marin",
#         "city_name": "San Rafael",
#         "cbsa_code": "41860",
#         "cbsa_name": "San Francisco-Oakland-Hayward, CA",
#         "csa_code": "488",
#         "csa_name": "San Jose-San Francisco-Oakland, CA",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# Since there are no stations in Lewiston, I found stations in the 50 mile radius with data starting from 1986 to 2023. The information for these stations are below
#
# "state_code": "06",
# "county_code": "055",
# "open_date": "1986-11-04",
# "close_date": "2016-10-17",
#
#
# "state_code": "06",
# "county_code": "055",
# "site_number": "0004",
# "parameter_code": "81102",
# "poc": 1,
# "parameter_name": "PM10 Total 0-10um STP",
# "open_date": "2018-04-02",
# "close_date": "2021-05-25",
#
#
# "state_code": "53",
# "county_code": "075",
# "open_date": "2002-10-01",
# "close_date": '2023-10-31'

# %%
stations_dict = {
    '1986': '06',
    '1987': '16069',
    '1988': '16069',
    '1989': '16069',
    '1990': '16069',
    '1991': '16069',
    '1992': '16069',
    '1993': '16069',
    '1994': '16069',
    '1995': '16069',
    '1996': '16069',
    '1997': '16069',
    '1998': '16069',
    '1999': '16069',
    '2000': '16069',
    '2001': '16069',
    '2002': '16069',
    '2003': '53075',
    '2004': '53075',
    '2005': '53075',
    '2006': '53075',
    '2007': '53075',
    '2008': '53075',
    '2009': '53075',
    '2010': '53075',
    '2011': '53075',
    '2012': '53075',
    '2013': '53075',
    '2014': '53075',
    '2015': '53075',
    '2016': '53075',
    '2017': '53075',
    '2018': '53075',
    '2019': '53075',
    '2020': '53075',
    '2021': '53075',
    '2022': '53075',
    '2023': '53075'
}

# %%
import numpy as np

# %%
aqi_year = {}
for year in range(1986, 2024):
    print(str(year))
    request_data = AQS_REQUEST_TEMPLATE.copy()
    request_data['email'] = USERNAME
    request_data['key'] = APIKEY
    request_data['param'] = AQI_PARAMS_PARTICULATES
    request_data['state'] = "06"
    request_data['county'] = "055"
    begin_date = str(year) + '0101'
    end_date = str(year) + '1231'
    particulate_aqi = request_daily_summary(request_template=request_data, begin_date=begin_date, end_date=end_date)
    aqi_list = []
    if particulate_aqi["Header"][0]['status'] == "Success":
        for i in range(len(particulate_aqi['Data'])):
            if particulate_aqi['Data'][i]['aqi'] is not None:
                aqi_list.append(particulate_aqi['Data'][i]['aqi'])
        avg_aqi = np.mean(aqi_list)
        aqi_year[year] = avg_aqi
    elif particulate_aqi["Header"][0]['status'].startswith("No data "):
        print(str(year) + "There is no data")
# Out:
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2022There is no data
# 2023
# 2023There is no data

# %%
aqi_year
# Out:
# {1986: 47.8,
#  1987: 29.80701754385965,
#  1988: 27.620689655172413,
#  1989: 28.721311475409838,
#  1990: 29.81967213114754,
#  1991: 29.416666666666668,
#  1992: 24.639344262295083,
#  1993: 23.59016393442623,
#  1994: 20.89830508474576,
#  1995: 18.21311475409836,
#  1996: 17.950819672131146,
#  1997: 16.916666666666668,
#  1998: 15.2,
#  1999: 16.566666666666666,
#  2000: 14.426229508196721,
#  2001: 21.688524590163933,
#  2002: 22.918032786885245,
#  2003: 18.65573770491803,
#  2004: 18.19672131147541,
#  2005: 15.703125,
#  2006: 19.484375,
#  2007: 44.39855072463768,
#  2008: 46.01442307692308,
#  2009: 35.13,
#  2010: 32.25,
#  2011: 38.509186351706035,
#  2012: 37.568888888888885,
#  2013: 43.25883432767324,
#  2014: 44.791427308882014,
#  2015: 39.08395934600088,
#  2016: 33.869624885635865,
#  2017: 47.96100278551532,
#  2018: 40.332250580046406,
#  2019: 24.14181152790485,
#  2020: 34.9925512104283,
#  2021: 29.414752116082227}

# %%
with open("aqi.json", 'w') as json_file:
    json.dump(aqi_year, json_file)

# %%
import pandas as pd
aqi = pd.DataFrame.from_dict(aqi_year, orient='index', columns = ["AQI"]).reset_index()
aqi.rename({'index':'Fire_Year'})
# Out:
#     index        AQI
# 0    1986  47.800000
# 1    1987  29.807018
# 2    1988  27.620690
# 3    1989  28.721311
# 4    1990  29.819672
# 5    1991  29.416667
# 6    1992  24.639344
# 7    1993  23.590164
# 8    1994  20.898305
# 9    1995  18.213115
# 10   1996  17.950820
# 11   1997  16.916667
# 12   1998  15.200000
# 13   1999  16.566667
# 14   2000  14.426230
# 15   2001  21.688525
# 16   2002  22.918033
# 17   2003  18.655738
# 18   2004  18.196721
# 19   2005  15.703125
# 20   2006  19.484375
# 21   2007  44.398551
# 22   2008  46.014423
# 23   2009  35.130000
# 24   2010  32.250000
# 25   2011  38.509186
# 26   2012  37.568889
# 27   2013  43.258834
# 28   2014  44.791427
# 29   2015  39.083959
# 30   2016  33.869625
# 31   2017  47.961003
# 32   2018  40.332251
# 33   2019  24.141812
# 34   2020  34.992551
# 35   2021  29.414752
